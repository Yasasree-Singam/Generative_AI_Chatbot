# %% [markdown]
# | **Company**         | **Interface / Product** | **Underlying Models**                                    |
# | ------------------- | ----------------------- | -------------------------------------------------------- |
# | **OpenAI**          | **ChatGPT**             | GPT-3, GPT-3.5, GPT-4, GPT-4o, GPT-5                     |
# |                     | **DALL·E**              | DALL·E 2, DALL·E 3 (image models)                        |
# |                     | **Whisper**             | Whisper (speech-to-text models: tiny → large)            |
# | **Google**          | **Bard**                | LaMDA → PaLM → **Gemini** (rebranded & upgraded)         |
# |                     | **Gemini**              | Gemini Nano, Gemini Pro, Gemini Ultra                    |
# | **Meta (Facebook)** | **Meta AI**             | **LLaMA** 1, LLaMA 2, LLaMA 3                            |
# | **Anthropic**       | **Claude**              | Claude 1, Claude 2, **Claude 3** (Haiku, Sonnet, Opus)   |
# | **Microsoft**       | **Copilot**             | GPT-4, GPT-4o (via OpenAI partnership)                   |
# | **Amazon**          | **Bedrock / Alexa**     | **Titan** (Text, Embeddings, Image), internal Alexa LLMs |
#
# - AWS -> CodeWhisperer

# %% [markdown]
# #### AI
#
# -> broad field of computer science which focuses on creating intelligent systems capable of performing tasks that typically require human intelligence.
#
# #### Machine Learning
#
# -> subset of AI to develop algos and models capable of learning and make predictions or decisions without explicit programming (without human involvment)
#
#     - Lots of training data
#     - Computational power (GPU's)
#     - Algorithms
#
# #### Deep Learning
#
# -> subset of ML that focuses on teaching computers to learn and make decisions by processing data through neural networks inspired by brain
#     neurons are multiple layers (Neural Networks)
#     better results in case of complex problems
#
#
# Generative AI -> subset of deep learning
#
# Coventional AI - input data -> AI system -> prediction, classification, clustering, NLP, Computer vision
#
# Generative AI - more input data -> AI system -> Generate (Text, images, Audio, Video, Source code)
#
#               - large volume  of data
#               - high computational power
#               - conversational, contextual understanding
#
# Chatgpt -> language model developed by openAI, it is designed for Natural Language understanding and generation, specifically in a conversational context
#
#     - Generative AI application
#     - developed by open AI (Azure cloud)
#     - trained on billions of documents (570GB)
#     - based on generative pre-trained transformer (GPT) architecture, a type of neural networks
#     - web interface for end-users, API for developers
#
#
# #### LLM
#
# -> powerful AI models designed for understanding and generating human-like **text**.
#
#         - Tranformers (NN's) understands the text and delivering the output
#         - one word at a time
#
#         *Pre-Training - trained on huge corpus of data*
#         *size and scale - Massive neural networks*
#         *Fine-Tuning* - more "targeted" training for specific tasks
#
#
#         **Use Cases**
#
#             - context generation - marketing, advertising
#             - chatbots and virtual assistants - user support, interaction
#             - Language translation - expand communication
#             - Text summarizarion - reduce lengthy context
#             - Q&A - answer questions, provide information
#
# #### Prompt Engineering
#
# Prompt is a specific question, command or input provided to an AI system to request a particular response, information or action
#
#     - Text generation
#     - creative writing
#     - image generation
#     - code generation
#
# process of crafting well-defined and structured input queries to interact with AI systems, in order to get accurate and revelant responses.
#
# **Best practices for prompt engineering:**
#
#     - Clearly convey desired response
#     - provide context or background information
#     - balance simplicity and complexity
#     - iterative testing and refinement
#
#
# ##### Embeddings
#
#     - numerical representation of text
#     - essential for AI models to undertand and work better with human language effectively
#
# ##### Fine Tuning
#
#     - Process of adapting a pre-trained model to perform specific tasks or to cater to a particular domain more effectively
#
#     1. Self-Supervised - specific data
#     2. Supervised - Labeled data
#     3. Reinforcement learning - based on scores btw bad and good data
#
#     It is
#
#         - not about creating intelligence from scratch
#         - not about eliminating data requirement
#         - not a single universal solution
#         - not a magical one time process
#
# #### Use Cases:
#
# ##### Software Development
#
#     - Build
#     - Testing
#     - Requirement Generation
#     - Documentation
#
# ##### Retail
#
#     - Product Recommendation
#     - Supply Chain Optimization
#     - Customer Support
#     - Sentiment Analysis
#
# ##### Marketing
#
#     - Content Generation
#     - Search Engine Optimization (SEO)
#     - Market Research
#
#
#
# #### Why do we need responsible AI
#
#     - Bias & Descrimination
#     - Privacy concerns
#     - Legal consequences
#     - Loss of trust
#
# #### To implement responsible AI
#
#     - ethical principles
#     - data quality
#     - transperency
#     - consent & compliance
#     - monitor & improve
#     - human in the loop

# %%
import pandas as pd

for i in
